# %% [markdown]
# # Lab 2 - Control Structure

# %% [markdown]
# In this lab, we are going to learn the Python condition statements.
#
# Python checks the condition statement by evaluating the following common logical conditions
#
# Given that `a = 1` and `b = 3`
#
# |logical operations | logical operators| example| results|
# |-|:-:|:-:|-|
# |Equals | == | a==b| False|
# |Not equals | != | a!=b | True|
# |Less than | < | a<b | True |
# |Less than or eqauls to | <= | a<=b | True|
# |Greater than | > | a>b | False|
# |Greater than or eqauls to | >= | a>=b | False|

# %%
# Try the logical operators
a = 1
b = 2

a == b
# Out:
# False

# %% [markdown]
# **Exercise 1**
# 1. set variable `a` equals 5
# 2. set variable `b` equals 10
# 3. check whether `a` is smaller than `b`
# 4. check whether the sum of two `a` equals `b`
# 5. check whether `b` minus `a` is `a`
# 6. check whether `a` is an even number.

# %%
# Exercise 1
# your code begins here

# %% [markdown]
# ### 2.1 If else statement
#
# You can have better control in code execution in Python by using control statements.
#
# The most commonly used control statement is `if` statement.

# %%
# Example
a = 1
b = 3

if a < b:
    print("a is smaller than b")
else:
    print("a is larger than b")
# Out:
# a is smaller than b

# %% [markdown]
# Please note that the code inside `if` and `else` conditions are indented.
#
# Python uses indentation to represent a **block** of code at different levels.
#
# ![if else](images/lab02_if_else.png)

# %%
# Example
# the following code will return you an error
# Example
a = 1
b = 3

if a < b:
print("a is smaller than b")
else:
print("a is larger than b")
# Out:
#   File "<ipython-input-4-7eaffa56a0e9>", line 8
#     print("a is smaller than b")
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ### 2.2 Elif Statement
#
# The `elif` keyword tells Python to try this condition if the previous condition is not true.

# %%
# Example

a = 3
b = 3

if a < b:
    print("a is smaller than b")
elif a == b:
    print("a equals to b")
# Out:
# a equals to b

# %% [markdown]
# ### 2.3 Logic operators
#
# In Python, you can perform the logic operation by using the logic operators
#
# The truth tables for `and` and `or` are:
#
# | A| B| A and B|
# |:-:|:-:|:-:|
# |T|T|T|
# |T|F|F|
# |F|T|F|
# |F|F|F|
#
#
# | A| B| A or B|
# |:-:|:-:|:-:|
# |T|T|T|
# |T|F|T|
# |F|T|T|
# |F|F|F|

# %%
#example

marks = 40
grade = 'F'

if marks > 0 and marks < 40:
    grade = 'F'
elif marks >=40 and marks < 60:
    grade = 'D'
elif marks >=60 and marks < 70:
    grade = 'C'
elif marks >=70 and marks < 80:
    grade = 'B'
elif marks >=80:
    grade = 'A'
    
print("Your grade is " + grade)

# %% [markdown]
# ### 2.3 Looping
#
# Python has two common types of loop
# 1. The `while` loop
# 2. The `for` loop
#
# #### While Loop
# We use the `while` loop for executing a set of statements **as long as a condition is true**
#
#
# #### For Loop
# We use `for` loop for executing a set of statements **for a specified number of times** or **for iterating over a list**
#
# The keyword `continue` inside the `while` or `for` loop will make Python stop the current iteration of the loop and continue with the next
#
# The keyword `break` inside the `while` or `for` loop will make Python quit the loop.

# %%
#Example 1: while loop

i = 1

while i < 10:
    print(i)
    i = i + 1

# %%
#Example 2: while loop with break
i = 10

while i>0:
    print(i)
    i -= 1
    if (i == 5):
        break

# %%
#Example 3: while loop with continue

i = 1

while i < 10:
    i = i + 1
    if i == 3:
        i += 1
        continue
    print(i)

# %%
#Example 4: for loop with list

subjects = ["BHMSxxxx", "BHMS3323", "BHMSyyyy"]

for subject in subjects:
    addon = "."
    if subject == "BHMS3323":
        addon = ", I love this subject much!"
    print("I am studying " + subject + addon)

# %%
#Example 5: for loop with range

for i in range(10):
    print(i)

# %% [markdown]
# ### End of Tutorial 2
#
# *More Python tutorials can be found on [w3schools.com](https://www.w3schools.com/python/default.asp), I strongly recommend you to study the materials on your own.*
