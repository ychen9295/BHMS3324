# %% [markdown]
# ## BHMS3323 Practices of FinTech

# %% [markdown]
# ## Lab6 - Class

# %% [markdown]
# Python is an object-oriented programming language.
#
# In Python, you can define a variable as an object that has properties and methods.
#
# To create a class, we can use the keyword `class`.

# %% [markdown]
# For example, we can define a Circle in the Cartesian system by specifying its centre's x and y coordinates as `a` and `b` and its radius `r`.
#
# *Note: The class name should always begin with capital letter*

# %%
class Circle:
    a = 5
    b = 5
    r = 2

# %%
circle = Circle() #create a new instance of Circle
circle.a
# Out:
# 5

# %% [markdown]
# Now, let's create 2 circles.
#
# Circle A with (a,b) = (3,4) and r = 2
#
# Circle B with (a,b) = (6,8) and r = 4

# %%
circleA = Circle()
circleB = Circle()

# Circle A's properties
circleA.a = 3
circleA.b = 4
circleA.r = 2

# Circle B's properties
circleB.a = 6
circleB.b = 8
circleB.r = 4

# %% [markdown]
# The above method is a bit tedious, and actually, we can initialize the object properties by calling the *constructor* method when creating an object.
#
# The constructor method in Python is `__init__()`.
#
# We will use `self` keyword to reference the object itself. Let's define the class `Circle` again.
#
# *Note: The first argument of the `__init__()` function must be `self`.*

# %%
class Circle:
    def __init__(self, a, b, r):
        self.a = a
        self.b = b
        self.r = r

# %% [markdown]
# Now, let's create 2 circles again.
#
# Circle A with (a,b) = (3,4) and r = 2
#
# Circle B with (a,b) = (6,8) and r = 4

# %%
circle_A = Circle(3,4,2)
circle_B = Circle(a=6, b=8, r=4)

print(circle_A.r)
# Out:
# 2

# %% [markdown]
# You can define methods for your self-defined object.
#
# For example, we want to create a method `details()` that returns all the properties of `Circle`.

# %%
class Circle:
    def __init__(self, a, b, r):
        self.a = a
        self.b = b
        self.r = r
    
    def details(self):
        print("Circle center is ({a}, {b}), and the radius is {r}.".format(a=self.a, b=self.b, r=self.r))

# %%
circle_A = Circle(3,4,2)
circle_B = Circle(a=6, b=8, r=4)

circle_A.details()
circle_B.details()
# Out:
# Circle center is (3, 4), and the radius is 2.
# Circle center is (6, 8), and the radius is 4.

# %%
print(circle_A)
# Out:
# <__main__.Circle object at 0x00000262FC1FAD30>

# %% [markdown]
# If you run the code above, you will get an object reference used by Python internally instead of something meaningful.
#
# We can override the `__str()__` function to give `Circle` a meaningful output.
#
# Let's move the codes in your `details()` method to the `__str()__` method.

# %%
class Circle:
    def __init__(self, a, b, r):
        self.a = a
        self.b = b
        self.r = r
    
    def __str__(self):
        return "Circle center is ({a}, {b}), and the radius is {r}.".format(a=self.a, b=self.b, r=self.r)

# %%
# create the 2 circles
circle_A = Circle(3,4,2)
circle_B = Circle(a=6, b=8, r=4)

print(circle_A)
print(circle_B)

# %% [markdown]
# ### Modify Object Properties
#
# You can modify properties on an object by assigning value to it.
#
# `circle_A.r = 7`

# %%
circle_A = Circle(3,4,2)
print(circle_A)

# modify the properties
circle_A.a = 4
circle_A.r = 10
print(circle_A)
# Out:
# Circle center is (3, 4), and the radius is 2.
# Circle center is (4, 4), and the radius is 10.

# %% [markdown]
# ### Operators Overriding

# %% [markdown]
# Python supports both function and operator overriding. Method overriding is a concept of object-oriented programming that allows us to change the implementation of a function in the child class defined in the parent class. A child class can change the behaviour of a method already defined in its parent class (ancestors). With operator overriding, we can change the meaning of a Python operator within the scope of a class.
#
# The common Python operator and its methods are:
#
# | Operator | methods |  | Comparison Operator | methods |
# | :-: | :- | :-: | :-: | -: |
# | + | `__add(self, other)__`| | < | `__lt(self, other)__`|
# | - | `__sub(self, other)__`| | > | `__gt(self, other)__`|
# | * | `__mul(self, other)__`| | == | `__eq(self, other)__`|
# | / | `__truediv(self, other)__`| | != | `__ne(self, other)__`|

# %% [markdown]
# Now, let's modify the `Circle` class and overriding the `==` comparison operator.

# %%
# Before overriding

class Circle:
    def __init__(self, a, b, r):
        self.a = a
        self.b = b
        self.r = r
    
    def __str__(self):
        return "Circle center is ({a}, {b}), and the radius is {r}.".format(a=self.a, b=self.b, r=self.r)
    

circle_A = Circle(3,4,2)
circle_B = Circle(3,4,2)

# The == operator compare that memory address, but not the values of center and radius.
circle_A == circle_B
# Out:
# False

# %%
# overriding example

class Circle:
    def __init__(self, a, b, r):
        self.a = a
        self.b = b
        self.r = r
    
    def __str__(self):
        return "Circle center is ({a}, {b}), and the radius is {r}.".format(a=self.a, b=self.b, r=self.r)
    
    def __eq__(self, other):
        if self.a == other.a and self.b == other.b and self.r == other.r:
            return True
        else:
            return False
    

circle_A = Circle(3,4,2)
circle_B = Circle(3,4,2)

# The == operator compare that memory address, but not the values of center and radius.
circle_A == circle_B
# Out:
# True

# %%
if circle_A == circle_B:
    print("They are same circle.")
else:
    print("They are different circle.")
# Out:
# They are same circle.
